# %%
#Import the dependencies.
import pandas as pd
import numpy as np
import requests

#Import the citipy module to determine city based on latitude and longitude.
from citipy import citipy

#Import the API key.
from config_copy import weather_api_key

# %%
#Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Create a list for holding the cities.
cities = []

#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 737

# %%
#Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key + "&q="

# %%
#Create an empty list to hold the weather data.
city_data = []

#Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

#Loop through all the cities in list.
for i, city in enumerate(cities):

    #Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        #time.sleep(60)
        
    #Create endpoint URL with each city.
    city_url = url + city.replace(" ","+")
    
    #Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #Add 1 to the record count.
    record_count += 1
    
    #Run an API request for each of the cities.
    try:
        #Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        #Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descrip = city_weather["weather"][0]["description"]
        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_descrip})

    #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

#Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | portland
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | bambous virieux
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | saskylakh
# Processing Record 8 of Set 1 | luena
# Processing Record 9 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 1 | esperance
# Processing Record 11 of Set 1 | east london
# Processing Record 12 of Set 1 | ilulissat
# Processing Record 13 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 1 | severnoye
# Processing Record 15 of Set 1 | piacabucu
# Processing Record 16 of Set 1 | saint-philippe
# Processing Record 17 of Set 1 | faanui
# Processing Record 18 of Set 1 | koch bihar
# Processing Record 19 of Set 1 | atlantic city
# Processing Record 20 of Set 1 | hilo
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | hambantota
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | orange
# Processing Record 25 of Set 1 | saint george
# Processing Record 26 of Set 1 | san luis
# Processing Record 27 of Set 1 | hervey bay
# Processing Record 28 of Set 1 | ponta do sol
# Processing Record 29 of Set 1 | zarautz
# Processing Record 30 of Set 1 | athabasca
# Processing Record 31 of Set 1 | port elizabeth
# Processing Record 32 of Set 1 | aranos
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | carnarvon
# Processing Record 35 of Set 1 | bengkulu
# Processing Record 36 of Set 1 | yenagoa
# Processing Record 37 of Set 1 | iqaluit
# Processing Record 38 of Set 1 | lazaro cardenas
# Processing Record 39 of Set 1 | bundaberg
# Processing Record 40 of Set 1 | tasiilaq
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | hofn
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | challans
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | new norfolk
# Processing Record 47 of Set 1 | borba
# Processing Record 48 of Set 1 | chuy
# Processing Record 49 of Set 1 | tuktoyaktuk
# Processing Record 50 of Set 1 | senmonorom
# City not found. Skipping...
# Processing Record 1 of Set 2 | arraial do cabo
# Processing Record 2 of Set 2 | port-gentil
# Processing Record 3 of Set 2 | avarua
# Processing Record 4 of Set 2 | cariati
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | cidreira
# Processing Record 7 of Set 2 | asau
# Processing Record 8 of Set 2 | busselton
# Processing Record 9 of Set 2 | narni
# Processing Record 10 of Set 2 | arlit
# Processing Record 11 of Set 2 | atuona
# Processing Record 12 of Set 2 | nome
# Processing Record 13 of Set 2 | ola
# Processing Record 14 of Set 2 | nikolskoye
# Processing Record 15 of Set 2 | ballina
# Processing Record 16 of Set 2 | north bend
# Processing Record 17 of Set 2 | sahrak
# City not found. Skipping...
# Processing Record 18 of Set 2 | alofi
# Processing Record 19 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 2 | jamestown
# Processing Record 21 of Set 2 | guarapari
# Processing Record 22 of Set 2 | rocha
# Processing Record 23 of Set 2 | barrow
# Processing Record 24 of Set 2 | barranca
# Processing Record 25 of Set 2 | waipawa
# Processing Record 26 of Set 2 | yaan
# Processing Record 27 of Set 2 | luderitz
# Processing Record 28 of Set 2 | bluff
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | bathsheba
# Processing Record 31 of Set 2 | thompson
# Processing Record 32 of Set 2 | guerrero negro
# Processing Record 33 of Set 2 | havre-saint-pierre
# Processing Record 34 of Set 2 | amparafaravola
# Processing Record 35 of Set 2 | coquimbo
# Processing Record 36 of Set 2 | lebu
# Processing Record 37 of Set 2 | kunda
# Processing Record 38 of Set 2 | iberia
# Processing Record 39 of Set 2 | hithadhoo
# Processing Record 40 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 2 | kibuye
# Processing Record 42 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 2 | albany
# Processing Record 45 of Set 2 | torbay
# Processing Record 46 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 2 | yellowknife
# Processing Record 48 of Set 2 | butaritari
# Processing Record 49 of Set 2 | aswan
# Processing Record 50 of Set 2 | santa cruz de la palma
# Processing Record 1 of Set 3 | cape town
# Processing Record 2 of Set 3 | faya
# Processing Record 3 of Set 3 | hyeres
# Processing Record 4 of Set 3 | estelle
# Processing Record 5 of Set 3 | sulina
# Processing Record 6 of Set 3 | victoria
# Processing Record 7 of Set 3 | viedma
# Processing Record 8 of Set 3 | cherskiy
# Processing Record 9 of Set 3 | khatanga
# Processing Record 10 of Set 3 | port blair
# Processing Record 11 of Set 3 | biak
# Processing Record 12 of Set 3 | muisne
# Processing Record 13 of Set 3 | bethel
# Processing Record 14 of Set 3 | cabo san lucas
# Processing Record 15 of Set 3 | lompoc
# Processing Record 16 of Set 3 | ribeira grande
# Processing Record 17 of Set 3 | tartagal
# Processing Record 18 of Set 3 | oga
# Processing Record 19 of Set 3 | souillac
# Processing Record 20 of Set 3 | qaanaaq
# Processing Record 21 of Set 3 | pevek
# Processing Record 22 of Set 3 | eskasem
# City not found. Skipping...
# Processing Record 23 of Set 3 | banda aceh
# Processing Record 24 of Set 3 | shreveport
# Processing Record 25 of Set 3 | deep river
# Processing Record 26 of Set 3 | nouadhibou
# Processing Record 27 of Set 3 | belaya gora
# Processing Record 28 of Set 3 | fortuna
# Processing Record 29 of Set 3 | longyearbyen
# Processing Record 30 of Set 3 | usinsk
# Processing Record 31 of Set 3 | oranjemund
# Processing Record 32 of Set 3 | tarakan
# Processing Record 33 of Set 3 | chokurdakh
# Processing Record 34 of Set 3 | mahebourg
# Processing Record 35 of Set 3 | watsa
# Processing Record 36 of Set 3 | naftah
# City not found. Skipping...
# Processing Record 37 of Set 3 | carutapera
# Processing Record 38 of Set 3 | okhotsk
# Processing Record 39 of Set 3 | laguna
# Processing Record 40 of Set 3 | nanortalik
# Processing Record 41 of Set 3 | cockburn town
# Processing Record 42 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 3 | provideniya
# Processing Record 44 of Set 3 | syntul
# Processing Record 45 of Set 3 | tiksi
# Processing Record 46 of Set 3 | anderson
# Processing Record 47 of Set 3 | korla
# Processing Record 48 of Set 3 | shimoda
# Processing Record 49 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 50 of Set 3 | auki
# Processing Record 1 of Set 4 | kruisfontein
# Processing Record 2 of Set 4 | constitucion
# Processing Record 3 of Set 4 | atambua
# Processing Record 4 of Set 4 | sumbe
# Processing Record 5 of Set 4 | pochutla
# Processing Record 6 of Set 4 | cayenne
# Processing Record 7 of Set 4 | castro
# Processing Record 8 of Set 4 | bredasdorp
# Processing Record 9 of Set 4 | sao filipe
# Processing Record 10 of Set 4 | pangai
# Processing Record 11 of Set 4 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 12 of Set 4 | taoudenni
# Processing Record 13 of Set 4 | labrea
# Processing Record 14 of Set 4 | yanam
# Processing Record 15 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 4 | puerto ayora
# Processing Record 17 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 4 | boyolangu
# Processing Record 19 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 20 of Set 4 | potiskum
# Processing Record 21 of Set 4 | klaksvik
# Processing Record 22 of Set 4 | upernavik
# Processing Record 23 of Set 4 | butterworth
# Processing Record 24 of Set 4 | harper
# Processing Record 25 of Set 4 | ossora
# Processing Record 26 of Set 4 | vila franca do campo
# Processing Record 27 of Set 4 | ilo
# Processing Record 28 of Set 4 | norman wells
# Processing Record 29 of Set 4 | saint-pierre
# Processing Record 30 of Set 4 | katherine
# Processing Record 31 of Set 4 | hamilton
# Processing Record 32 of Set 4 | white rock
# Processing Record 33 of Set 4 | bafq
# Processing Record 34 of Set 4 | chara
# Processing Record 35 of Set 4 | maceio
# Processing Record 36 of Set 4 | hof
# Processing Record 37 of Set 4 | lodja
# Processing Record 38 of Set 4 | ostrovnoy
# Processing Record 39 of Set 4 | moctezuma
# Processing Record 40 of Set 4 | adre
# Processing Record 41 of Set 4 | dongsheng
# Processing Record 42 of Set 4 | lorengau
# Processing Record 43 of Set 4 | vanimo
# Processing Record 44 of Set 4 | kahului
# Processing Record 45 of Set 4 | wahiawa
# Processing Record 46 of Set 4 | lamesa
# Processing Record 47 of Set 4 | lagoa
# Processing Record 48 of Set 4 | kaitangata
# Processing Record 49 of Set 4 | talnakh
# Processing Record 50 of Set 4 | roald
# Processing Record 1 of Set 5 | san patricio
# Processing Record 2 of Set 5 | kijang
# Processing Record 3 of Set 5 | mandalgovi
# Processing Record 4 of Set 5 | keti bandar
# Processing Record 5 of Set 5 | dauriya
# Processing Record 6 of Set 5 | komsomolskiy
# Processing Record 7 of Set 5 | gravdal
# Processing Record 8 of Set 5 | umm lajj
# Processing Record 9 of Set 5 | ko samui
# Processing Record 10 of Set 5 | jieshi
# Processing Record 11 of Set 5 | hutchinson
# Processing Record 12 of Set 5 | venado
# Processing Record 13 of Set 5 | hermagor
# Processing Record 14 of Set 5 | valparai
# Processing Record 15 of Set 5 | haines junction
# Processing Record 16 of Set 5 | svetlyy
# Processing Record 17 of Set 5 | americus
# Processing Record 18 of Set 5 | berezovyy
# Processing Record 19 of Set 5 | yumen
# Processing Record 20 of Set 5 | barth
# Processing Record 21 of Set 5 | san jeronimito
# Processing Record 22 of Set 5 | fort nelson
# Processing Record 23 of Set 5 | esmeraldas
# Processing Record 24 of Set 5 | olafsvik
# Processing Record 25 of Set 5 | kita
# Processing Record 26 of Set 5 | hohhot
# Processing Record 27 of Set 5 | amga
# Processing Record 28 of Set 5 | touros
# Processing Record 29 of Set 5 | kodiak
# Processing Record 30 of Set 5 | colares
# Processing Record 31 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 5 | namatanai
# Processing Record 33 of Set 5 | krasnaya polyana
# Processing Record 34 of Set 5 | san juan
# Processing Record 35 of Set 5 | porto novo
# Processing Record 36 of Set 5 | los llanos de aridane
# Processing Record 37 of Set 5 | portel
# Processing Record 38 of Set 5 | sibi
# Processing Record 39 of Set 5 | shasta lake
# Processing Record 40 of Set 5 | onega
# Processing Record 41 of Set 5 | samarai
# Processing Record 42 of Set 5 | katsuura
# Processing Record 43 of Set 5 | kavieng
# Processing Record 44 of Set 5 | tabou
# Processing Record 45 of Set 5 | margate
# Processing Record 46 of Set 5 | guanica
# Processing Record 47 of Set 5 | leirvik
# Processing Record 48 of Set 5 | maghama
# City not found. Skipping...
# Processing Record 49 of Set 5 | kamyshin
# Processing Record 50 of Set 5 | oistins
# Processing Record 1 of Set 6 | sao jose da coroa grande
# Processing Record 2 of Set 6 | karamay
# City not found. Skipping...
# Processing Record 3 of Set 6 | san pedro
# Processing Record 4 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 6 | kant
# Processing Record 6 of Set 6 | severo-kurilsk
# Processing Record 7 of Set 6 | yichun
# Processing Record 8 of Set 6 | ketchikan
# Processing Record 9 of Set 6 | shitanjing
# Processing Record 10 of Set 6 | ponta delgada
# Processing Record 11 of Set 6 | fayaoue
# Processing Record 12 of Set 6 | tessalit
# Processing Record 13 of Set 6 | narsaq
# Processing Record 14 of Set 6 | parsons
# Processing Record 15 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 6 | blackwater
# Processing Record 17 of Set 6 | salaga
# Processing Record 18 of Set 6 | redmond
# Processing Record 19 of Set 6 | port lincoln
# Processing Record 20 of Set 6 | richards bay
# Processing Record 21 of Set 6 | parkes
# Processing Record 22 of Set 6 | el jicaro
# Processing Record 23 of Set 6 | gigmoto
# Processing Record 24 of Set 6 | surt
# Processing Record 25 of Set 6 | hovd
# Processing Record 26 of Set 6 | yerazgavors
# Processing Record 27 of Set 6 | san cristobal
# Processing Record 28 of Set 6 | mingyue
# Processing Record 29 of Set 6 | itarema
# Processing Record 30 of Set 6 | gao
# Processing Record 31 of Set 6 | opuwo
# Processing Record 32 of Set 6 | hay river
# Processing Record 33 of Set 6 | carauari
# Processing Record 34 of Set 6 | port hardy
# Processing Record 35 of Set 6 | priverno
# Processing Record 36 of Set 6 | mitsamiouli
# Processing Record 37 of Set 6 | stornoway
# Processing Record 38 of Set 6 | chapais
# Processing Record 39 of Set 6 | sisimiut
# Processing Record 40 of Set 6 | totness
# Processing Record 41 of Set 6 | bandarbeyla
# Processing Record 42 of Set 6 | eenhana
# Processing Record 43 of Set 6 | mitu
# Processing Record 44 of Set 6 | tevaitoa
# Processing Record 45 of Set 6 | varadero
# Processing Record 46 of Set 6 | barpathar
# Processing Record 47 of Set 6 | pathein
# Processing Record 48 of Set 6 | zakamensk
# Processing Record 49 of Set 6 | san isidro
# Processing Record 50 of Set 6 | suzdal
# Processing Record 1 of Set 7 | innisfail
# Processing Record 2 of Set 7 | mount isa
# Processing Record 3 of Set 7 | chicama
# Processing Record 4 of Set 7 | paripiranga
# Processing Record 5 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 6 of Set 7 | pisco
# Processing Record 7 of Set 7 | wajima
# Processing Record 8 of Set 7 | georgetown
# Processing Record 9 of Set 7 | verkhnyaya inta
# Processing Record 10 of Set 7 | saint-francois
# Processing Record 11 of Set 7 | hastings
# Processing Record 12 of Set 7 | yangambi
# Processing Record 13 of Set 7 | port macquarie
# Processing Record 14 of Set 7 | urumqi
# Processing Record 15 of Set 7 | mar del plata
# Processing Record 16 of Set 7 | grand-santi
# Processing Record 17 of Set 7 | namibe
# Processing Record 18 of Set 7 | varhaug
# Processing Record 19 of Set 7 | husavik
# Processing Record 20 of Set 7 | hella
# Processing Record 21 of Set 7 | fairbanks
# Processing Record 22 of Set 7 | humaita
# Processing Record 23 of Set 7 | sangar
# Processing Record 24 of Set 7 | binzhou
# Processing Record 25 of Set 7 | ixtapa
# Processing Record 26 of Set 7 | kinel-cherkassy
# Processing Record 27 of Set 7 | college
# Processing Record 28 of Set 7 | anadyr
# Processing Record 29 of Set 7 | kodinsk
# Processing Record 30 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 7 | salme
# Processing Record 32 of Set 7 | san policarpo
# Processing Record 33 of Set 7 | caravelas
# Processing Record 34 of Set 7 | cairns
# Processing Record 35 of Set 7 | rudnogorsk
# Processing Record 36 of Set 7 | sitka
# Processing Record 37 of Set 7 | lasa
# Processing Record 38 of Set 7 | luganville
# Processing Record 39 of Set 7 | saint-augustin
# Processing Record 40 of Set 7 | lavrentiya
# Processing Record 41 of Set 7 | udachnyy
# Processing Record 42 of Set 7 | glodeni
# Processing Record 43 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 7 | tuatapere
# Processing Record 45 of Set 7 | kirovsk
# Processing Record 46 of Set 7 | cooma
# Processing Record 47 of Set 7 | villazon
# Processing Record 48 of Set 7 | saint marys
# Processing Record 49 of Set 7 | batagay-alyta
# Processing Record 50 of Set 7 | preobrazheniye
# Processing Record 1 of Set 8 | maraba
# Processing Record 2 of Set 8 | dunedin
# Processing Record 3 of Set 8 | pudozh
# Processing Record 4 of Set 8 | ginda
# Processing Record 5 of Set 8 | sur
# Processing Record 6 of Set 8 | isangel
# Processing Record 7 of Set 8 | grand gaube
# Processing Record 8 of Set 8 | tochio
# Processing Record 9 of Set 8 | beringovskiy
# Processing Record 10 of Set 8 | saint anthony
# Processing Record 11 of Set 8 | verkhoyansk
# Processing Record 12 of Set 8 | bulqize
# Processing Record 13 of Set 8 | shingu
# Processing Record 14 of Set 8 | mbalmayo
# Processing Record 15 of Set 8 | ures
# Processing Record 16 of Set 8 | madisonville
# Processing Record 17 of Set 8 | santiago del estero
# Processing Record 18 of Set 8 | kavaratti
# Processing Record 19 of Set 8 | kabalo
# Processing Record 20 of Set 8 | phangnga
# Processing Record 21 of Set 8 | bubaque
# Processing Record 22 of Set 8 | uyemskiy
# Processing Record 23 of Set 8 | broken hill
# Processing Record 24 of Set 8 | buala
# Processing Record 25 of Set 8 | trincomalee
# Processing Record 26 of Set 8 | vuktyl
# Processing Record 27 of Set 8 | acarau
# Processing Record 28 of Set 8 | manta
# Processing Record 29 of Set 8 | isla vista
# Processing Record 30 of Set 8 | cabedelo
# Processing Record 31 of Set 8 | teknaf
# Processing Record 32 of Set 8 | henties bay
# Processing Record 33 of Set 8 | kempten
# Processing Record 34 of Set 8 | havoysund
# Processing Record 35 of Set 8 | goure
# Processing Record 36 of Set 8 | thinadhoo
# Processing Record 37 of Set 8 | bosaso
# Processing Record 38 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 8 | tyazhinskiy
# Processing Record 40 of Set 8 | kankon
# Processing Record 41 of Set 8 | lensk
# Processing Record 42 of Set 8 | mount gambier
# Processing Record 43 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 44 of Set 8 | uyuni
# Processing Record 45 of Set 8 | zhezkazgan
# Processing Record 46 of Set 8 | anito
# Processing Record 47 of Set 8 | otjiwarongo
# Processing Record 48 of Set 8 | ambilobe
# Processing Record 49 of Set 8 | ushtobe
# Processing Record 50 of Set 8 | bridlington
# Processing Record 1 of Set 9 | axim
# Processing Record 2 of Set 9 | rabo de peixe
# Processing Record 3 of Set 9 | wukari
# Processing Record 4 of Set 9 | tadine
# Processing Record 5 of Set 9 | ifakara
# Processing Record 6 of Set 9 | kidal
# Processing Record 7 of Set 9 | nishihara
# Processing Record 8 of Set 9 | kletskaya
# Processing Record 9 of Set 9 | libertador general san martin
# Processing Record 10 of Set 9 | kokopo
# Processing Record 11 of Set 9 | along
# Processing Record 12 of Set 9 | bakchar
# Processing Record 13 of Set 9 | rudbar
# Processing Record 14 of Set 9 | talca
# Processing Record 15 of Set 9 | vanavara
# Processing Record 16 of Set 9 | trairi
# Processing Record 17 of Set 9 | nara
# Processing Record 18 of Set 9 | amahai
# Processing Record 19 of Set 9 | tura
# Processing Record 20 of Set 9 | ancud
# Processing Record 21 of Set 9 | ofunato
# Processing Record 22 of Set 9 | ewa beach
# Processing Record 23 of Set 9 | kabanjahe
# Processing Record 24 of Set 9 | san felipe
# Processing Record 25 of Set 9 | vilyuysk
# Processing Record 26 of Set 9 | sao cristovao
# Processing Record 27 of Set 9 | egvekinot
# Processing Record 28 of Set 9 | takoradi
# Processing Record 29 of Set 9 | manado
# Processing Record 30 of Set 9 | muros
# Processing Record 31 of Set 9 | porterville
# Processing Record 32 of Set 9 | brae
# Processing Record 33 of Set 9 | zhigansk
# Processing Record 34 of Set 9 | alta
# Processing Record 35 of Set 9 | berdigestyakh
# Processing Record 36 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 37 of Set 9 | matara
# Processing Record 38 of Set 9 | bakaly
# Processing Record 39 of Set 9 | pakxan
# Processing Record 40 of Set 9 | dali
# Processing Record 41 of Set 9 | iracoubo
# Processing Record 42 of Set 9 | doka
# Processing Record 43 of Set 9 | karratha
# Processing Record 44 of Set 9 | tahoua
# Processing Record 45 of Set 9 | wasilla
# Processing Record 46 of Set 9 | nago
# Processing Record 47 of Set 9 | victoria point
# Processing Record 48 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 49 of Set 9 | bay roberts
# Processing Record 50 of Set 9 | saldanha
# Processing Record 1 of Set 10 | rongcheng
# Processing Record 2 of Set 10 | baft
# Processing Record 3 of Set 10 | omboue
# Processing Record 4 of Set 10 | vardo
# Processing Record 5 of Set 10 | melilla
# Processing Record 6 of Set 10 | tilichiki
# Processing Record 7 of Set 10 | rio grande
# Processing Record 8 of Set 10 | jumla
# Processing Record 9 of Set 10 | avera
# Processing Record 10 of Set 10 | la ronge
# Processing Record 11 of Set 10 | anahuac
# Processing Record 12 of Set 10 | milici
# Processing Record 13 of Set 10 | puteyets
# Processing Record 14 of Set 10 | baependi
# Processing Record 15 of Set 10 | quebo
# Processing Record 16 of Set 10 | batemans bay
# Processing Record 17 of Set 10 | talas
# Processing Record 18 of Set 10 | sola
# Processing Record 19 of Set 10 | jalu
# Processing Record 20 of Set 10 | sokolo
# Processing Record 21 of Set 10 | jishou
# Processing Record 22 of Set 10 | mana
# Processing Record 23 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 25 of Set 10 | hitachi
# Processing Record 26 of Set 10 | jangipur
# Processing Record 27 of Set 10 | skiathos
# Processing Record 28 of Set 10 | te anau
# Processing Record 29 of Set 10 | inuvik
# Processing Record 30 of Set 10 | two rivers
# Processing Record 31 of Set 10 | tiarei
# Processing Record 32 of Set 10 | sabla
# Processing Record 33 of Set 10 | altay
# Processing Record 34 of Set 10 | broome
# Processing Record 35 of Set 10 | narrabri
# Processing Record 36 of Set 10 | naze
# Processing Record 37 of Set 10 | enumclaw
# Processing Record 38 of Set 10 | cacu
# Processing Record 39 of Set 10 | la victoria
# Processing Record 40 of Set 10 | kuching
# Processing Record 41 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 42 of Set 10 | ocumare del tuy
# Processing Record 43 of Set 10 | dingle
# Processing Record 44 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 10 | new braunfels
# Processing Record 46 of Set 10 | muravlenko
# Processing Record 47 of Set 10 | wollongong
# Processing Record 48 of Set 10 | abu jubayhah
# City not found. Skipping...
# Processing Record 49 of Set 10 | urucara
# Processing Record 50 of Set 10 | killam
# Processing Record 1 of Set 11 | burnie
# Processing Record 2 of Set 11 | taichung
# Processing Record 3 of Set 11 | half moon bay
# Processing Record 4 of Set 11 | krasnyy chikoy
# Processing Record 5 of Set 11 | rawson
# Processing Record 6 of Set 11 | tres arroyos
# Processing Record 7 of Set 11 | kharp
# Processing Record 8 of Set 11 | koutsouras
# Processing Record 9 of Set 11 | goderich
# Processing Record 10 of Set 11 | krasnokamensk
# Processing Record 11 of Set 11 | lincoln
# Processing Record 12 of Set 11 | bilibino
# Processing Record 13 of Set 11 | puerto escondido
# Processing Record 14 of Set 11 | bengkalis
# City not found. Skipping...
# Processing Record 15 of Set 11 | granville
# Processing Record 16 of Set 11 | doha
# Processing Record 17 of Set 11 | huamachuco
# Processing Record 18 of Set 11 | beloha
# Processing Record 19 of Set 11 | corn island
# Processing Record 20 of Set 11 | honningsvag
# Processing Record 21 of Set 11 | iquique
# Processing Record 22 of Set 11 | geraldton
# Processing Record 23 of Set 11 | taganak
# Processing Record 24 of Set 11 | grootfontein
# Processing Record 25 of Set 11 | vao
# Processing Record 26 of Set 11 | marsa matruh
# Processing Record 27 of Set 11 | sanchursk
# Processing Record 28 of Set 11 | belmonte
# Processing Record 29 of Set 11 | key west
# Processing Record 30 of Set 11 | tautira
# Processing Record 31 of Set 11 | antoniny
# Processing Record 32 of Set 11 | partizanskoye
# Processing Record 33 of Set 11 | ahipara
# Processing Record 34 of Set 11 | vestbygda
# City not found. Skipping...
# Processing Record 35 of Set 11 | nyamuswa
# Processing Record 36 of Set 11 | rodenbach
# Processing Record 37 of Set 11 | galgani
# City not found. Skipping...
# Processing Record 38 of Set 11 | fuglebjerg
# Processing Record 39 of Set 11 | yasenskaya
# Processing Record 40 of Set 11 | ranong
# Processing Record 41 of Set 11 | akyab
# Processing Record 42 of Set 11 | roebourne
# Processing Record 43 of Set 11 | troitskoye
# Processing Record 44 of Set 11 | toowoomba
# Processing Record 45 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 46 of Set 11 | santa lucia
# Processing Record 47 of Set 11 | berlevag
# Processing Record 48 of Set 11 | huaral
# Processing Record 49 of Set 11 | turukhansk
# Processing Record 50 of Set 11 | lulea
# Processing Record 1 of Set 12 | tayu
# Processing Record 2 of Set 12 | zeya
# Processing Record 3 of Set 12 | ust-omchug
# Processing Record 4 of Set 12 | samur
# Processing Record 5 of Set 12 | mayumba
# Processing Record 6 of Set 12 | codrington
# Processing Record 7 of Set 12 | verkhnevilyuysk
# Processing Record 8 of Set 12 | vestmannaeyjar
# Processing Record 9 of Set 12 | agbor
# Processing Record 10 of Set 12 | xingyi
# Processing Record 11 of Set 12 | leningradskiy
# Processing Record 12 of Set 12 | magan
# Processing Record 13 of Set 12 | kutum
# Processing Record 14 of Set 12 | sorland
# Processing Record 15 of Set 12 | pacifica
# Processing Record 16 of Set 12 | miyako
# Processing Record 17 of Set 12 | leh
# Processing Record 18 of Set 12 | ellsworth
# Processing Record 19 of Set 12 | yalta
# Processing Record 20 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 21 of Set 12 | ostersund
# Processing Record 22 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 12 | el faiyum
# City not found. Skipping...
# Processing Record 24 of Set 12 | nivala
# Processing Record 25 of Set 12 | bonthe
# Processing Record 26 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 12 | tambopata
# Processing Record 28 of Set 12 | palembang
# Processing Record 29 of Set 12 | kendari
# Processing Record 30 of Set 12 | airai
# Processing Record 31 of Set 12 | camocim
# Processing Record 32 of Set 12 | mareeba
# Processing Record 33 of Set 12 | jurilovca
# Processing Record 34 of Set 12 | svetlaya
# Processing Record 35 of Set 12 | muli
# Processing Record 36 of Set 12 | porto uniao
# Processing Record 37 of Set 12 | almaty
# Processing Record 38 of Set 12 | torrington
# Processing Record 39 of Set 12 | cananeia
# Processing Record 40 of Set 12 | andros town
# Processing Record 41 of Set 12 | manzhouli
# Processing Record 42 of Set 12 | perry
# Processing Record 43 of Set 12 | lima
# Processing Record 44 of Set 12 | phan thiet
# Processing Record 45 of Set 12 | ceres
# Processing Record 46 of Set 12 | lahaina
# Processing Record 47 of Set 12 | novyy urengoy
# Processing Record 48 of Set 12 | visnes
# Processing Record 49 of Set 12 | vagur
# Processing Record 50 of Set 12 | durango
# Processing Record 1 of Set 13 | yerofey pavlovich
# Processing Record 2 of Set 13 | demir kapija
# Processing Record 3 of Set 13 | kasongo-lunda
# Processing Record 4 of Set 13 | tezu
# Processing Record 5 of Set 13 | taloqan
# Processing Record 6 of Set 13 | pyshchug
# Processing Record 7 of Set 13 | labuhan
# Processing Record 8 of Set 13 | lebedinyy
# Processing Record 9 of Set 13 | palatca
# Processing Record 10 of Set 13 | arteaga
# Processing Record 11 of Set 13 | kracheh
# City not found. Skipping...
# Processing Record 12 of Set 13 | nikel
# Processing Record 13 of Set 13 | acapulco
# Processing Record 14 of Set 13 | prince george
# Processing Record 15 of Set 13 | alyangula
# Processing Record 16 of Set 13 | sorong
# Processing Record 17 of Set 13 | remagen
# Processing Record 18 of Set 13 | moose factory
# Processing Record 19 of Set 13 | vostok
# Processing Record 20 of Set 13 | ilam
# Processing Record 21 of Set 13 | naqadeh
# Processing Record 22 of Set 13 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 13 | semnan
# Processing Record 24 of Set 13 | calama
# Processing Record 25 of Set 13 | kapit
# Processing Record 26 of Set 13 | domoni
# Processing Record 27 of Set 13 | linao
# Processing Record 28 of Set 13 | sale
# Processing Record 29 of Set 13 | tuy hoa
# Processing Record 30 of Set 13 | juneau
# Processing Record 31 of Set 13 | ilhabela
# Processing Record 32 of Set 13 | gobabis
# Processing Record 33 of Set 13 | bonavista
# Processing Record 34 of Set 13 | road town
# Processing Record 35 of Set 13 | santa vitoria do palmar
# Processing Record 36 of Set 13 | spruce grove
# Processing Record 37 of Set 13 | san vicente
# Processing Record 38 of Set 13 | pindiga
# Processing Record 39 of Set 13 | mahanje
# Processing Record 40 of Set 13 | pangnirtung
# Processing Record 41 of Set 13 | praia
# Processing Record 42 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 43 of Set 13 | porto torres
# Processing Record 44 of Set 13 | lukovetskiy
# Processing Record 45 of Set 13 | chalons-en-champagne
# Processing Record 46 of Set 13 | xiaolingwei
# Processing Record 47 of Set 13 | tanout
# Processing Record 48 of Set 13 | canita
# Processing Record 49 of Set 13 | vrangel
# Processing Record 50 of Set 13 | pauini
# Processing Record 1 of Set 14 | gat
# Processing Record 2 of Set 14 | nancha
# Processing Record 3 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 4 of Set 14 | pemangkat
# Processing Record 5 of Set 14 | kontagora
# Processing Record 6 of Set 14 | salalah
# Processing Record 7 of Set 14 | atasu
# Processing Record 8 of Set 14 | san carlos
# Processing Record 9 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 10 of Set 14 | dien bien
# City not found. Skipping...
# Processing Record 11 of Set 14 | witu
# Processing Record 12 of Set 14 | yulara
# Processing Record 13 of Set 14 | paytug
# City not found. Skipping...
# Processing Record 14 of Set 14 | northam
# Processing Record 15 of Set 14 | pankrushikha
# Processing Record 16 of Set 14 | hamburg
# Processing Record 17 of Set 14 | bar harbor
# Processing Record 18 of Set 14 | teguldet
# Processing Record 19 of Set 14 | tamara
# Processing Record 20 of Set 14 | severo-yeniseyskiy
# Processing Record 21 of Set 14 | isakly
# Processing Record 22 of Set 14 | grindavik
# Processing Record 23 of Set 14 | roma
# Processing Record 24 of Set 14 | albacete
# Processing Record 25 of Set 14 | hasaki
# Processing Record 26 of Set 14 | worland
# Processing Record 27 of Set 14 | cabra
# Processing Record 28 of Set 14 | luanda
# Processing Record 29 of Set 14 | kuremaa
# Processing Record 30 of Set 14 | seoul
# Processing Record 31 of Set 14 | uni
# Processing Record 32 of Set 14 | vila velha
# Processing Record 33 of Set 14 | olinda
# Processing Record 34 of Set 14 | kasane
# Processing Record 35 of Set 14 | comodoro rivadavia
# Processing Record 36 of Set 14 | georgiyevskoye
# Processing Record 37 of Set 14 | noyabrsk
# Processing Record 38 of Set 14 | flinders
# Processing Record 39 of Set 14 | mossendjo
# Processing Record 40 of Set 14 | vanderhoof
# Processing Record 41 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 42 of Set 14 | talakan
# Processing Record 43 of Set 14 | bainbridge
# Processing Record 44 of Set 14 | octeville
# Processing Record 45 of Set 14 | yar-sale
# Processing Record 46 of Set 14 | zaranj
# Processing Record 47 of Set 14 | bairiki
# Processing Record 48 of Set 14 | port moresby
# Processing Record 49 of Set 14 | skala fourkas
# Processing Record 50 of Set 14 | belfast
# Processing Record 1 of Set 15 | abu samrah
# Processing Record 2 of Set 15 | sao joao da barra
# Processing Record 3 of Set 15 | ijaki
# City not found. Skipping...
# Processing Record 4 of Set 15 | sinnamary
# Processing Record 5 of Set 15 | nabire
# Processing Record 6 of Set 15 | walvis bay
# Processing Record 7 of Set 15 | sobolevo
# Processing Record 8 of Set 15 | nalut
# Processing Record 9 of Set 15 | cap malheureux
# Processing Record 10 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 11 of Set 15 | gondanglegi
# Processing Record 12 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 13 of Set 15 | el alto
# Processing Record 14 of Set 15 | bose
# Processing Record 15 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 16 of Set 15 | yashkul
# Processing Record 17 of Set 15 | almeirim
# Processing Record 18 of Set 15 | pavda
# City not found. Skipping...
# Processing Record 19 of Set 15 | bira
# Processing Record 20 of Set 15 | dicabisagan
# Processing Record 21 of Set 15 | dryden
# Processing Record 22 of Set 15 | koppang
# Processing Record 23 of Set 15 | obidos
# Processing Record 24 of Set 15 | beian
# Processing Record 25 of Set 15 | iquitos
# Processing Record 26 of Set 15 | kingsport
# Processing Record 27 of Set 15 | kalach-na-donu
# Processing Record 28 of Set 15 | port washington
# Processing Record 29 of Set 15 | kholodnyy
# Processing Record 30 of Set 15 | nosy varika
# Processing Record 31 of Set 15 | parry sound
# Processing Record 32 of Set 15 | arco
# Processing Record 33 of Set 15 | nam som
# Processing Record 34 of Set 15 | palampur
# Processing Record 35 of Set 15 | kouqian
# Processing Record 36 of Set 15 | kieta
# Processing Record 37 of Set 15 | babu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 681

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Rikitea -23.1203 -134.9692     74.86        80         100
# 1            Kapaa  22.0752 -159.3190     80.58        76           1
# 2         Portland  45.5234 -122.6762     57.36        86          90
# 3      Port Alfred -33.5906   26.8910     66.56        82          85
# 4  Bambous Virieux -20.3428   57.7575     74.21        73          20
# 5        Saskylakh  71.9167  114.0833      0.39        98         100
# 6            Luena -11.7833   19.9167     62.58        94          99
# 7        Esperance -33.8667  121.9000     48.04        91           5
# 8      East London -33.0153   27.9116     66.88        81          86
# 9        Ilulissat  69.2167  -51.1000     14.02        52          20
#
#    Wind Speed Country Current Description
# 0       18.63      PF          light rain
# 1        3.00      US           clear sky
# 2        3.00      US          light rain
# 3       29.17      ZA     overcast clouds
# 4       14.79      MU          few clouds
# 5        1.57      RU     overcast clouds
# 6        1.07      AO       moderate rain
# 7       12.64      AU           clear sky
# 8       20.22      ZA     overcast clouds
# 9        3.44      GL          few clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Rikitea      PF -23.1203 -134.9692     74.86        80         100
# 1            Kapaa      US  22.0752 -159.3190     80.58        76           1
# 2         Portland      US  45.5234 -122.6762     57.36        86          90
# 3      Port Alfred      ZA -33.5906   26.8910     66.56        82          85
# 4  Bambous Virieux      MU -20.3428   57.7575     74.21        73          20
# 5        Saskylakh      RU  71.9167  114.0833      0.39        98         100
# 6            Luena      AO -11.7833   19.9167     62.58        94          99
# 7        Esperance      AU -33.8667  121.9000     48.04        91           5
# 8      East London      ZA -33.0153   27.9116     66.88        81          86
# 9        Ilulissat      GL  69.2167  -51.1000     14.02        52          20
#
#    Wind Speed Current Description
# 0       18.63          light rain
# 1        3.00           clear sky
# 2        3.00          light rain
# 3       29.17     overcast clouds
# 4       14.79          few clouds
# 5        1.57     overcast clouds
# 6        1.07       moderate rain
# 7       12.64           clear sky
# 8       20.22     overcast clouds
# 9        3.44          few clouds

# %%
#Create output file as CSV.
output_data_file = "WeatherPy_Database.csv"

#Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
