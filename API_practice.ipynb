# %%
#Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
#Use the tuple() function to display the latitude and longitude combinations.
#for coordinate in coordinates:
#    print(coordinate[0], coordinate[1])

# %%
#Import the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
#Use tuple function to display lat and lng combos
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0],coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0],coordinate[1]).country_code)
# Out:
# cockburn town tc
# gat ly
# parvatsar in
# punta arenas cl
# saint george bm

# %%
#Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
#Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?"
city = "London"

# %%
query_url = url + "appid=" + weather_api_key + "&q=" + city
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=138a4472f9a9c8af3b4a1b5eca153c4c&q=London'

# %%
weather_response = requests.get(query_url)
weather_json = weather_response.json()
weather_json
# Out:
# {'coord': {'lon': -0.1257, 'lat': 51.5085},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 286.76,
#   'feels_like': 286.29,
#   'temp_min': 285.68,
#   'temp_max': 287.35,
#   'pressure': 1016,
#   'humidity': 81},
#  'visibility': 10000,
#  'wind': {'speed': 2.57, 'deg': 180},
#  'clouds': {'all': 75},
#  'dt': 1635095262,
#  'sys': {'type': 2,
#   'id': 2019646,
#   'country': 'GB',
#   'sunrise': 1635057597,
#   'sunset': 1635094149},
#  'timezone': 3600,
#  'id': 2643743,
#  'name': 'London',
#  'cod': 200}

# %%
weather_json.keys()
# Out:
# dict_keys(['coord', 'weather', 'base', 'main', 'visibility', 'wind', 'clouds', 'dt', 'sys', 'timezone', 'id', 'name', 'cod'])

# %%
weather_json.get("main")
# Out:
# {'temp': 286.76,
#  'feels_like': 286.29,
#  'temp_min': 285.68,
#  'temp_max': 287.35,
#  'pressure': 1016,
#  'humidity': 81}

# %%
#Create an endpoint URL for a city.
city_url = url + "appid=" + weather_api_key + "&q="  + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=138a4472f9a9c8af3b4a1b5eca153c4c&q=Boston

# %%
#Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
city_weather.status_code
# Out:
# 200

# %%
#Create an endpoint URL for a city.
city_url = url + "appid=" + weather_api_key + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
#Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02d"}],"base":"stations","main":{"temp":285.82,"feels_like":284.32,"temp_min":284.11,"temp_max":287.96,"pressure":1020,"humidity":45},"visibility":10000,"wind":{"speed":3.13,"deg":314,"gust":7.6},"clouds":{"all":20},"dt":1635095217,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1635073671,"sunset":1635112120},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
#Get the text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 285.82,
#   'feels_like': 284.32,
#   'temp_min': 284.11,
#   'temp_max': 287.96,
#   'pressure': 1020,
#   'humidity': 45},
#  'visibility': 10000,
#  'wind': {'speed': 3.13, 'deg': 314, 'gust': 7.6},
#  'clouds': {'all': 20},
#  'dt': 1635095217,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1635073671,
#   'sunset': 1635112120},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "appid=" + weather_api_key + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=138a4472f9a9c8af3b4a1b5eca153c4c&q=Boston

# %%
#Get json data.
boston_data = city_weather.json()

# %%
boston_data["sys"]["country"]
# Out:
# 'US'

# %%
#Extract specific data from json data.
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 287.96 45 20 3.13

# %%
#Import the datetime module from the datetime library.
from datetime import datetime

#Get the date from the JSON file.
date = boston_data["dt"]

# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2021-10-24 17:06:57'
